# %%
import pandas as pd

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data',header=None,names=['age','sex','cp','trestbps','chol','fbs','restecg','thalacg','exang','oldpeak','scope','ca','thal','num'])
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalacg  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    scope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
import seaborn as sn
#%matplotlib inline

# %%
sn.pairplot(data, x_vars=['age','trestbps','chol'], y_vars='num',size=7,aspect=1)

# %%
data.plot()

# %%
data.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalacg     float64
# exang       float64
# oldpeak     float64
# scope       float64
# ca           object
# thal         object
# num           int64
# patient       int64
# dtype: object

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalacg       exang     oldpeak       scope         num  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
def checkcancer(i):
    if i>0:
        return 1
    else:
        return 0

# %%
data['patient']=pd.Series((checkcancer(i)) for i in data.num)

# %%
def checkgender(i):
    if i==1:
        return "male"
    else:
        return "female"

# %%
data['gender']=pd.Series((checkgender(i)) for i in data.sex)

# %%
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalacg  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    scope   ca thal  num  patient  gender
# 0    3.0  0.0  6.0    0        0    male
# 1    2.0  3.0  3.0    2        1    male
# 2    2.0  2.0  7.0    1        1    male
# 3    3.0  0.0  3.0    0        0    male
# 4    1.0  0.0  3.0    0        0  female

# %%
sn.pairplot(data, x_vars=['age','trestbps','chol'], y_vars='patient',size=7,aspect=1)

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalacg       exang     oldpeak       scope         num  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12c3f7a90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d4ccc90>]], dtype=object)

# %%
plt.hist(data.age.dropna(),bins=25)
plt.xlabel('Age')
plt.ylabel('Frequency')

# %%
plt.hist(data.chol.dropna(),bins=25,color=sn.desaturate('indianred',1))
# Out:
# (array([  3.,   4.,  15.,  16.,  46.,  41.,  45.,  38.,  32.,  19.,  22.,
#          11.,   4.,   2.,   0.,   1.,   3.,   0.,   0.,   0.,   0.,   0.,
#           0.,   0.,   1.]),
#  array([ 126.  ,  143.52,  161.04,  178.56,  196.08,  213.6 ,  231.12,
#          248.64,  266.16,  283.68,  301.2 ,  318.72,  336.24,  353.76,
#          371.28,  388.8 ,  406.32,  423.84,  441.36,  458.88,  476.4 ,
#          493.92,  511.44,  528.96,  546.48,  564.  ]),
#  <a list of 25 Patch objects>)

# %%
sn.boxplot(data.age.dropna(),data.gender,orient='h')

# %%
sn.kdeplot(data.age,shade=True)

# %%
sn.distplot(data.age)

# %%
sn.violinplot(data.age.dropna())

# %%
sn.violinplot(data.age.dropna(),data.gender,orient="h")

# %%
sn.kdeplot(data.age,cumulative=True)
